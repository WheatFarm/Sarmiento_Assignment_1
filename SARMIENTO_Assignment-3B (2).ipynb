# %% [markdown]
# # ITMGT 25.03 EE
# # Assignment 3B
#
# This is a data-cleaning assignment and is the second of two parts. This notebook is uploaded to our Github repository along with a csv of fake, dirty data called **recweekdata.csv**.
#
# In addition, you have a new file called **studentprofiles.csv** which has first and last names plus the genders of the students.
#
# The output of this assignment is to convert recweekdata.csv into processable data for statistics. Submit the following files through GitHub:
# 1. A cleaned recweekdata.csv called **cleanrecweekdata3b.csv** **(5 points)**
# 2. This notebook, containing the code (properly commented) that you used to clean the data **(5 points)**
# 3. An html file of summary statistics from each column called **stats3b.html**. The requirements for the summary statistics are described below. **(10 points)**
#
# The outputs are similar to that of Assignment 3A, except that you will now use Pandas instead of Python lists.
#
# This entire assignment (3B) is worth 20 points.
#
# Upload your output files to your Github repositories. Make sure to send an email to **joben.ilagan@gmail.com** once you're done.
#
# This assignment is due on **Monday, July 9, 2019** at 12:00NN.
#
# Note: I understand you all need to review for LT 2. Think of this Assignment as practice. It's not meant to take you as long as 3A.
#
# #### Bonus Points:
# * +2 if submitted over (or before) the weekend (July 13-14)
# * +2 if CSS and div tags are used (but please don't spend too much time on this because you still need to review for the Long Test)

# %%
import pandas as pd
import re

# %%
df1= pd.read_csv("recweekdata.csv")

# %%
df1.loc[:,"phonenumber"].replace("^9","+63 9",regex=True, inplace=True)

# %%
df= pd.read_csv("studentprofiles.csv")

# %%
df
# Out:
#      firstname      lastname  gender
# 0        name1     lastname1  Female
# 1        name2     lastname2  Female
# 2        name3     lastname3  Female
# 3        name4     lastname4    Male
# 4        name5     lastname5  Female
# 5        name6     lastname6  Female
# 6        name7     lastname7  Female
# 7        name8     lastname8    Male
# 8        name9     lastname9    Male
# 9       name10    lastname10  Female
# 10      name11    lastname11    Male
# 11      name12    lastname12    Male
# 12      name13    lastname13  Female
# 13      name14    lastname14  Female
# 14      name15    lastname15    Male
# 15      name16    lastname16    Male
# 16      name17    lastname17  Female
# 17      name18    lastname18  Female
# 18      name19    lastname19    Male
# 19      name20    lastname20    Male
# 20      name21    lastname21  Female
# 21      name22    lastname22    Male
# 22      name23    lastname23    Male
# 23      name24    lastname24    Male
# ...

# %%
df1.loc[:,"birthmonth"].replace("^January", "1", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^February", "2", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^March", "3", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^April", "4", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^May", "5", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^June", "6", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^July", "7", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^August", "8", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^September", "9", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^October", "10", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^November", "11", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^December", "12", regex = True, inplace = True)

# %%
df1.loc[:,"birthmonth"].replace("^Jan", "1", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Feb", "2", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Mar", "3", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Apr", "4", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^May", "5", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Jun", "6", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Jul", "7", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Aug", "8", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Sept", "9", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Sep", "9", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Oct", "10", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Nov", "11", regex = True, inplace = True)
df1.loc[:,"birthmonth"].replace("^Dec", "12", regex = True, inplace = True)

# %%
df1.loc[:,"course"].replace("^BS ME", "Management Engineering", regex = True, inplace = True)
df1.loc[:,"course"].replace("^BS LM", "Legal Management", regex = True, inplace = True)
df1.loc[:,"course"].replace("^BS MGT", "Management", regex = True, inplace = True)
df1.loc[:,"course"].replace("^BS CTM", "Communications Technology", regex = True, inplace = True)
df1.loc[:,"course"].replace("^BS ITE", "Information Technology Entrepreneurship", regex = True, inplace = True)

# %%
df1.loc[:,"course"].replace("^ME", "Management Engineering", regex = True, inplace = True)
df1.loc[:,"course"].replace("^LM", "Legal Management", regex = True, inplace = True)
df1.loc[:,"course"].replace("^MGT", "Management", regex = True, inplace = True)
df1.loc[:,"course"].replace("^CTM", "Communications Technology", regex = True, inplace = True)
df1.loc[:,"course"].replace("^ITE", "Information Technology Entrepreneurship", regex = True, inplace = True)

# %%
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^97","1997", regex = True)
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^98","1998", regex = True)
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^99","1999", regex = True)
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^00","2000", regex = True)
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^01","2001", regex = True)

# %%
carrier = {"+63 917":"Globe","+63 918":"Smart", "+63 927":"Globe"}

# %%
df1.loc[:,"phonenumber"].str[0:7].apply(lambda x: carrier[x])
# Out:
# 0       Smart
# 1       Globe
# 2       Smart
# 3       Smart
# 4       Globe
# 5       Smart
# 6       Globe
# 7       Globe
# 8       Smart
# 9       Smart
# 10      Globe
# 11      Globe
# 12      Globe
# 13      Globe
# 14      Globe
# 15      Smart
# 16      Globe
# 17      Globe
# 18      Globe
# 19      Globe
# 20      Globe
# 21      Globe
# 22      Globe
# 23      Globe
# 24      Smart
# 25      Globe
# 26      Globe
# 27      Globe
# 28      Globe
# 29      Globe
#         ...
# 2970    Smart
# 2971    Globe
# 2972    Globe
# 2973    Globe
# 2974    Globe
# 2975    Globe
# 2976    Smart
# 2977    Smart
# 2978    Smart
# 2979    Smart
# 2980    Globe
# 2981    Globe
# 2982    Smart
# 2983    Globe
# 2984    Globe
# 2985    Globe
# 2986    Smart
# 2987    Globe
# 2988    Globe
# 2989    Globe
# 2990    Smart
# 2991    Globe
# 2992    Globe
# 2993    Globe
# 2994    Globe
# 2995    Globe
# 2996    Globe
# 2997    Globe
# 2998    Globe
# 2999    Smart
# ...

# %%
df1["carrier"] = df1.loc[:,"phonenumber"].str[0:7].apply(lambda x: carrier[x])

# %%
df1
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1         11        26      1998
# 1        name2     lastname2          5        26      2001
# 2        name3     lastname3          5        16      1997
# 3        name4     lastname4         12         9      1997
# 4        name5     lastname5          9         5      1997
# 5        name6     lastname6          3         2      1999
# 6        name7     lastname7         11        10      1998
# 7        name8     lastname8          8        28      1999
# 8        name9     lastname9          7        10      1997
# 9       name10    lastname10          9        14      2001
# 10      name11    lastname11         12         8      1998
# 11      name12    lastname12          5         4      1997
# 12      name13    lastname13          1        28      1999
# 13      name14    lastname14          1        11      1999
# 14      name15    lastname15          6         6      1998
# ...

# %%
df1.to_csv("cleandataframe.csv")

# %%
cleandataframe = pd.read_csv("cleandataframe.csv")

# %%
pd.merge(df1, df, how="left",left_on=["firstname","lastname"], right_on=["firstname","lastname"])
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1         11        26      1998
# 1        name2     lastname2          5        26      2001
# 2        name3     lastname3          5        16      1997
# 3        name4     lastname4         12         9      1997
# 4        name5     lastname5          9         5      1997
# 5        name6     lastname6          3         2      1999
# 6        name7     lastname7         11        10      1998
# 7        name8     lastname8          8        28      1999
# 8        name9     lastname9          7        10      1997
# 9       name10    lastname10          9        14      2001
# 10      name11    lastname11         12         8      1998
# 11      name12    lastname12          5         4      1997
# 12      name13    lastname13          1        28      1999
# 13      name14    lastname14          1        11      1999
# 14      name15    lastname15          6         6      1998
# ...

# %%
merged_df=pd.merge(cleandataframe, df, how="left",left_on=["firstname","lastname"], right_on=["firstname","lastname"])

# %%
bmonth = merged_df.groupby(["lastname","birthmonth"])['firstname'].count()

# %%
jan = bmonth.count('birthmonth')[1]

# %%
feb = bmonth.count('birthmonth')[2]

# %%
mar = bmonth.count('birthmonth')[3]

# %%
apr = bmonth.count('birthmonth')[4]

# %%
may = bmonth.count('birthmonth')[5]

# %%
june = bmonth.count('birthmonth')[6]

# %%
july = bmonth.count('birthmonth')[7]

# %%
aug = bmonth.count('birthmonth')[8]

# %%
sept = bmonth.count('birthmonth')[9]

# %%
octo = bmonth.count('birthmonth')[10]

# %%
nov = bmonth.count('birthmonth')[11]

# %%
dec = bmonth.count('birthmonth')[12]

# %%
bday = merged_df.groupby(["lastname","birthday"])['firstname'].count()

# %%
day1 = bday.count('birthday')[1]

# %%
day2 = bday.count('birthday')[2]

# %%
day3 = bday.count('birthday')[3]

# %%
day4 = bday.count('birthday')[4]

# %%
day5 = bday.count('birthday')[5]

# %%
day6 = bday.count('birthday')[6]

# %%
day7 = bday.count('birthday')[7]

# %%
day8 = bday.count('birthday')[8]

# %%
day9 = bday.count('birthday')[9]

# %%
day10 = bday.count('birthday')[10]

# %%
day11 = bday.count('birthday')[11]

# %%
day12 = bday.count('birthday')[12]

# %%
day13 = bday.count('birthday')[13]

# %%
day14 = bday.count('birthday')[14]

# %%
day15 = bday.count('birthday')[15]

# %%
day16 = bday.count('birthday')[16]

# %%
day17 = bday.count('birthday')[17]

# %%
day18 = bday.count('birthday')[18]

# %%
day19 = bday.count('birthday')[19]

# %%
day20 = bday.count('birthday')[20]

# %%
day21 = bday.count('birthday')[21]

# %%
day22 = bday.count('birthday')[22]

# %%
day23 = bday.count('birthday')[23]

# %%
day24 = bday.count('birthday')[24]

# %%
day25 = bday.count('birthday')[25]

# %%
day26 = bday.count('birthday')[26]

# %%
day27 = bday.count('birthday')[27]

# %%
day28 = bday.count('birthday')[28]

# %%
byear = merged_df.groupby(["lastname","birthyear"])['firstname'].count()

# %%
byear97 = byear.count('birthyear')[1997]

# %%
byear98 = byear.count('birthyear')[1998]

# %%
byear99 = byear.count('birthyear')[1999]

# %%
byear00 = byear.count('birthyear')[2000]

# %%
byear01 = byear.count('birthyear')[2001]

# %%
cour = merged_df.groupby(["lastname","course"])['firstname'].count()

# %%
ctm = cour.count('course')["Communications Technology"]

# %%
ite = cour.count('course')["Information Technology Entrepreneurship"]

# %%
lm = cour.count('course')["Legal Management"]

# %%
mgt = cour.count('course')["Management"]

# %%
me = cour.count('course')["Management Engineering"]

# %%
car = merged_df.groupby(["gender","carrier"])['phonenumber'].count()

# %%
globe = car.count('carrier')["Globe"]

# %%
smart = car.count('carrier')["Smart"]

# %%
gencar = merged_df.groupby(["gender","carrier"])['firstname'].count()

# %%
globe_male = gencar[('Male','Globe')]

# %%
globe_female = gencar[('Female','Globe')]

# %%
smart_male = gencar[('Male','Smart')]

# %%
smart_female = gencar[('Female','Smart')]

# %% [markdown]
# # Required Summary Statistics
#
# #### These were the questions from 3A:
#
# 1. How many people were born in each month?
# 2. How many people were born on each day?
# 3. How many people were born in each year?
# 4. How many people come from each course?
# 5. How many people have numbers from Globe (0917 or 0927) and Smart (0918)? *Note: it's up to you how to format this output*
#
# #### Additional Questions:
# * How many Globe subscribers are: Male? Female?
# * How many Smart subscribers are: Male? Female?
#
# Answer these questions in an html file called **stats3b.html**. The format of the html is as follows (in template form, so you can use this as format string in your program, though feel free to modify with variable names if you find it easier to do so):

# %% [markdown]
# ```
# <html>
#     <body>
#          <h2>Summary Statistics</h2>
#          <table>
#              <tr><th>Stat</th><th>Value</th></tr>
#              <tr><td>People born in each month</td><td>{}</td></tr>
#              <tr><td>People born on each day</td><td>{}</td></tr>
#              <tr><td>People born in each year</td><td>{}</td></tr>
#              <tr><td>People coming from each course</td><td>{}</td></tr>
#              <tr><td>People having numbers from Globe and Smart</td><td>{}</td></tr>
#              <tr><td>Male Globe subscribers:</td><td>{}</td></tr>
#              <tr><td>Female Globe subscribers:</td><td>{}</td></tr>
#              <tr><td>Male Smart subscribers:</td><td>{}</td></tr>
#              <tr><td>Female Smart subscribers:</td><td>{}</td></tr>
#          </table>
#     </body>
# </html>
# ```

# %%
from IPython.core.display import HTML

html = """
<h1>Summary Statistics</h1>
<div class="divTable">
<div class="divTableBody">
<div class="divTableRow">
<div class="divTableCell"><strong>People born in each month</strong></div>
<div class="divTableCell"><br />
<div class="divTable">
<div class="divTableBody">
<div class="divTableRow">
<div class="divTableHead">January</div>
<div class="divTableHead">February</div>
<div class="divTableHead">March</div>
<div class="divTableHead">April</div>
<div class="divTableHead">May</div>
<div class="divTableHead">June</div>
<div class="divTableHead">July</div>
<div class="divTableHead">August</div>
<div class="divTableHead">September</div>
<div class="divTableHead">October</div>
<div class="divTableHead">November</div>
<div class="divTableHead">December</div>
</div>
<div class="divTableRow">
<div class="divTableCell">{jan}</div>
<div class="divTableCell">{feb}</div>
<div class="divTableCell">{mar}</div>
<div class="divTableCell">{apr}</div>
<div class="divTableCell">{may}</div>
<div class="divTableCell">{june}</div>
<div class="divTableCell">{july}</div>
<div class="divTableCell">{aug}</div>
<div class="divTableCell">{sept}</div>
<div class="divTableCell">{octo}</div>
<div class="divTableCell">{nov}</div>
<div class="divTableCell">{dec}</div>
</div>
</div>
</div>
</div>
</div>
<div class="divTableRow">
<div class="divTableCell"><strong>People born on each day</strong></div>
<div class="divTableCell">
<div class="divTable">
<div class="divTableBody">
<div class="divTableRow">
<div class="divTableHead">1</div>
<div class="divTableHead">2</div>
<div class="divTableHead">3</div>
<div class="divTableHead">4</div>
<div class="divTableHead">5</div>
<div class="divTableHead">6</div>
<div class="divTableHead">7</div>
<div class="divTableHead">8</div>
<div class="divTableHead">9</div>
<div class="divTableHead">10</div>
<div class="divTableHead">11</div>
<div class="divTableHead">12</div>
<div class="divTableHead">13</div>
<div class="divTableHead">14</div>
<div class="divTableHead">15</div>
<div class="divTableHead">16</div>
<div class="divTableHead">17</div>
<div class="divTableHead">18</div>
<div class="divTableHead">19</div>
<div class="divTableHead">20</div>
<div class="divTableHead">21</div>
<div class="divTableHead">22</div>
<div class="divTableHead">23</div>
<div class="divTableHead">24</div>
<div class="divTableHead">25</div>
<div class="divTableHead">26</div>
<div class="divTableHead">27</div>
<div class="divTableHead">28</div>
</div>
<div class="divTableRow">
<div class="divTableCell">{day1}</div>
<div class="divTableCell">{day2}</div>
<div class="divTableCell">{day3}</div>
<div class="divTableCell">{day4}</div>
<div class="divTableCell">{day5}</div>
<div class="divTableCell">{day6}</div>
<div class="divTableCell">{day7}</div>
<div class="divTableCell">{day8}</div>
<div class="divTableCell">{day9}</div>
<div class="divTableCell">{day10}</div>
<div class="divTableCell">{day11}</div>
<div class="divTableCell">{day12}</div>
<div class="divTableCell">{day13}</div>
<div class="divTableCell">{day14}</div>
<div class="divTableCell">{day15}</div>
<div class="divTableCell">{day16}</div>
<div class="divTableCell">{day17}</div>
<div class="divTableCell">{day18}</div>
<div class="divTableCell">{day19}</div>
<div class="divTableCell">{day20}</div>
<div class="divTableCell">{day21}</div>
<div class="divTableCell">{day22}</div>
<div class="divTableCell">{day23}</div>
<div class="divTableCell">{day24}</div>
<div class="divTableCell">{day25}</div>
<div class="divTableCell">{day26}</div>
<div class="divTableCell">{day27}</div>
<div class="divTableCell">{day28}</div>
</div>
</div>
</div>
</div>
</div>
<div class="divTableRow">
<div class="divTableCell"><strong>People born in each year</strong></div>
<div class="divTableCell">
<div class="divTable">
<div class="divTableBody">
<div class="divTableRow">
<div class="divTableHead">1997</div>
<div class="divTableHead">1998</div>
<div class="divTableHead">1999</div>
<div class="divTableHead">2000</div>
<div class="divTableHead">2001</div>
</div>
<div class="divTableRow">
<div class="divTableCell">{byear97}</div>
<div class="divTableCell">{byear98}</div>
<div class="divTableCell">{byear99}</div>
<div class="divTableCell">{byear00}</div>
<div class="divTableCell">{byear01}</div>
</div>
</div>
</div>
</div>
</div>
<div class="divTableRow">
<div class="divTableCell"><strong>People coming from each course</strong></div>
<div class="divTableCell">
<div class="divTable">
<div class="divTableBody">
<div class="divTableRow">
<div class="divTableHead">BS Communications Technology Management</div>
<div class="divTableHead">BS Information Technology Entrepreneurship</div>
<div class="divTableHead">BS Legal Management</div>
<div class="divTableHead">BS Management</div>
<div class="divTableHead">BS Management Engineering</div>
</div>
<div class="divTableRow">
<div class="divTableCell">{ctm}</div>
<div class="divTableCell">{ite}</div>
<div class="divTableCell">{lm}</div>
<div class="divTableCell">{mgt}</div>
<div class="divTableCell">{me}</div>
</div>
</div>
</div>
</div>
</div>
<div class="divTableRow">
<div class="divTableCell"><strong>People having numbers from Globe and Smart</strong></div>
<div class="divTableCell">
<div class="divTable">
<div class="divTableBody">
<div class="divTableRow">
<div class="divTableHead">Globe Users</div>
<div class="divTableHead">Smart Users</div>
</div>
<div class="divTableRow">
<div class="divTableCell">{globe}</div>
<div class="divTableCell">{smart}</div>
</div>
</div>
</div>
</div>
</div>
<div class="divTableRow">
<div class="divTableCell"><strong>People having numbers from Globe</strong></div>
<div class="divTableCell">
<div class="divTable">
<div class="divTableBody">
<div class="divTableRow">
<div class="divTableHead">Male Globe Users</div>
<div class="divTableHead">Female Globe Users</div>
</div>
<div class="divTableRow">
<div class="divTableCell">{globe_male}</div>
<div class="divTableCell">{globe_female}</div>
</div>
<div class="divTableRow">
<div class="divTableCell"><strong>People having numbers from Smart</strong></div>
<div class="divTableCell">
<div class="divTable">
<div class="divTableBody">
<div class="divTableRow">
<div class="divTableHead">Male Smart Users</div>
<div class="divTableHead">Female Smart Users</div>
</div>
<div class="divTableRow">
<div class="divTableCell">{smart_male}</div>
<div class="divTableCell">{smart_female}</div>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
"""

html_output = html.format(jan=jan,
                          feb = feb,
                          mar = mar,  
                          apr = apr,
                          may = may, 
                          june = june,
                          july = july,
                          aug = aug,
                          sept = sept,
                          octo = octo,
                          nov = nov,
                          dec = dec,
                          day1 = day1,
                          day2 = day2,
                          day3 = day3,
                          day4 = day4,
                          day5 = day5,
                          day6 = day6,
                          day7 = day7,
                          day8 = day8,
                          day9 = day9,
                          day10 = day10,
                          day11 = day11, 
                          day12 = day12,
                          day13 = day13,
                          day14 = day14,
                          day15 = day15,
                          day16 = day16,
                          day17 = day17,
                          day18 = day18,
                          day19 = day19,
                          day20 = day20,
                          day21 = day21, 
                          day22 = day22, 
                          day23 = day23,
                          day24 = day24, 
                          day25 = day25,
                          day26 = day26, 
                          day27 = day27,
                          day28 = day28,
                          byear97 = byear97,
                          byear98 = byear98,
                          byear99 = byear99,
                          byear00 = byear00,
                          byear01 = byear01,
                          ctm = ctm,
                          ite = ite,
                          lm = lm,
                          mgt = mgt,
                          me = me,
                          globe = int(gencar[('Male','Globe')]) + int(gencar[('Female','Globe')]),
                          smart = int(gencar[('Male','Smart')]) + int(gencar[('Female','Smart')]),
                          globe_male = globe_male,
                          globe_female = globe_female,
                          smart_male = smart_male,
                          smart_female = smart_female
                          ) 
                          
HTML(html_output)

with open('stats3b.html',"w") as file:
    file.write(html_output)
